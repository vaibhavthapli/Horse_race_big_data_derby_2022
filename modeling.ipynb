# %%
import pandas as pd
import numpy as np


import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score, GridSearchCV

from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

from sklearn.metrics import f1_score, roc_curve, auc, confusion_matrix, average_precision_score
from sklearn.metrics import precision_recall_curve
import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
# Read the train and test file
df_train = pd.read_csv('./data/train.csv', index_col=0)
df_test = pd.read_csv('./data/test.csv', index_col=0)

# %%
df_train.head(2)
# Out:
#                         horse_name horse_id       jockey  trainer  \
# finishing_position
# 3                   PACKING DRAGON     T230  M Barzalona  P F Yiu
# 3                        BEST HOPE     S102     N Callan  C H Yip
#
#                     actual_weight  declared_horse_weight  draw  win_odds  \
# finishing_position
# 3                             117                   1202    12       6.2
# 3                             129                   1100    12       6.3
#
#                      race_course                   race_class  ...  \
# finishing_position                                             ...
# 3                   Happy Valley                      Class 2  ...
# 3                   Happy Valley  Class 4 (Special Condition)  ...
#
#                                   race_name              track  Season  \
# finishing_position
# 3                        AUSTRALIA HANDICAP  TURF - "B" COURSE  Winter
# 3                   HO CHUNG RIVER HANDICAP  TURF - "B" COURSE  Spring
#
#                    recent_6_runs recent_ave_rank jockey_ave_rank  \
# finishing_position
# 3                    3/1/1/3/3/1            3.75        5.111111
# 3                      3/2/4/8/8            5.00        6.066800
#
#                     track_condition_id  race_course_id  track_id  season_id
# finishing_position
# 3                                    2               1         4          2
# 3                                    2               1         4          1
#
# [2 rows x 22 columns]
